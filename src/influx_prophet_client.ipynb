# %%
import pandas as pd
import time
from datetime import datetime, timedelta
from prophet import Prophet
from influxdb_client import InfluxDBClient, Point
from influxdb_client.client.write_api import SYNCHRONOUS

# %%
global org, token, url, bucket_inf 
bucket_inf = 'sensor_readings'
org = "zhanel.zhexenova@alumni.nu.edu.kz"
token = "Vhm0-oLYDgWW00dLfUercjIrDFvdYhYLY_n3aeYYkPyxiT_bh63cLrrAkgqYbshxGGPC3d4Uc2_e4KhjOGwDMg=="
# Store the URL of your InfluxDB instance
url="https://europe-west1-1.gcp.cloud2.influxdata.com"

# %%
client = InfluxDBClient(
   url=url,
   token=token,
   org=org
)

# %% [markdown]
# # Forecasting and query

# %%
def data_retriever(ds_time='-26h'):
    #making a query to influx to get humidity, temperature and gas values
    query = 'from(bucket: "sensor_readings")'\
        '|> range(start: '+ds_time+')'\
        '|> filter(fn: (r) => r["_measurement"] == "esp32")'\
        '|> filter(fn: (r) => r["GPS_lat"] == "44.507393")'\
        '|> filter(fn: (r) => r["GPS_lon"] == "11.356048")'\
        '|> filter(fn: (r) => r["ID"] == "ESP32_001")'\
        '|> filter(fn: (r) => r["_field"] == "humidity" or r["_field"] == "temperature" or r["_field"] == "gas")'\

    query_api = client.query_api()
    result = query_api.query(org=org, query=query)   
    # Getting values and timestamps from flux tables into lists     
    hum_raw = []
    tem_raw = []
    gas_raw = []

    for table in result:
        for record in table.records:
            if record.get_field() == 'humidity':
                hum_raw.append((record.get_value(), record.get_time()))
            if record.get_field() == 'temperature':
                tem_raw.append((record.get_value(), record.get_time()))  
            if record.get_field() == 'gas':
                gas_raw.append((record.get_value(), record.get_time()))    
            

    # Transforming influx query into dataframes adding 2 hours, because utc is behind by 2h   
    #print("=== influxdb query into dataframes ===")
    
    humidity=pd.DataFrame(hum_raw, columns=['y','ds'], index=None)
    humidity['ds'] = humidity['ds'].values.astype('<M8[s]')  
    humidity['ds'] = humidity['ds'].apply(lambda x: x+timedelta(hours = 2))
    # print('humidity:',humidity['y'][0])

    temperature=pd.DataFrame(tem_raw, columns=['y','ds'], index=None)
    temperature['ds'] = temperature['ds'].values.astype('<M8[s]')  
    temperature['ds'] = temperature['ds'].apply(lambda x: x+timedelta(hours = 2))
    # print('temp:', temperature['y'][0])

    gas=pd.DataFrame(gas_raw, columns=['y','ds'], index=None)
    gas['ds'] = gas['ds'].values.astype('<M8[s]') 
    gas['ds'] = gas['ds'].apply(lambda x: x+timedelta(hours = 2))
    # print('gas:',gas['y'][0])

    return humidity, temperature, gas

def predictor( df, time_future = 60):
    m = Prophet(yearly_seasonality = False, weekly_seasonality= False,daily_seasonality=False, changepoint_prior_scale=0.3)
    m.fit(df)  
    future = pd.DataFrame()
    future['ds'] = df['ds'][-1:]+timedelta(seconds = time_future)  
    fcst = m.predict(future)
    #print('Predicted value: ')
    #print( fcst[['ds','yhat']])
    return fcst

# %%
while True:       
        #start = time.time()
        print('Query sent to Influx at {0}'.format(datetime.now().strftime("%d-%m-%y %H:%M:%S")) )
        humidity, temperature, gas = data_retriever()
        #end = time.time()
        #print(f'Time spent on query:{end-start}' )
        print('Data fed to predictor at {0}'.format(datetime.now().strftime("%d-%m-%y %H:%M:%S")) )
        #start0 = time.time()
        pred_humidity = predictor(df = humidity)
        #end0 = time.time()
        #print(f'Time spent on humidity pred:{end0-start0}' )

        #start1 = time.time()
        pred_temp = predictor(df = temperature)
        #end1 = time.time()
        #print(f'Time spent on temperature pred:{end1-start1}' )

        #start2 = time.time()
        pred_gas = predictor(df = gas)
        #end2 = time.time()
        #print(f'Time spent on gas pred:{end2-start2}' )

        # Writing to influx

        write_api = client.write_api(write_options=SYNCHRONOUS)
        write_api.write(bucket_inf, org, Point("esp32") \
                .tag("GPS_lat", "44.507393") \
                .tag("GPS_lon", "11.356048") \
                .tag("ID","ESP32_001") \
                .field("temperature_predicted", str(pred_temp['yhat'][0])) \
                .time(pred_temp['ds'].apply(lambda x: x-timedelta(hours = 2))[0]) \
                .to_line_protocol()     )

        write_api.write(bucket_inf, org, Point("esp32") \
                .tag("GPS_lat", "44.507393") \
                .tag("GPS_lon", "11.356048") \
                .tag("ID","ESP32_001") \
                .field("hum_predicted", str(pred_humidity['yhat'][0])) \
                .time(pred_humidity['ds'].apply(lambda x: x-timedelta(hours = 2))[0]) \
                .to_line_protocol()     )    
        write_api.write(bucket_inf, org, Point("esp32") \
                .tag("GPS_lat", "44.507393") \
                .tag("GPS_lon", "11.356048") \
                .tag("ID","ESP32_001") \
                .field("gas_predicted", str(pred_gas['yhat'][0])) \
                .time(pred_gas['ds'].apply(lambda x: x-timedelta(hours = 2))[0]) \
                .to_line_protocol()     )  
        print('Data sent to Influx at {0}: Temperature-{1:.2f}, Humidity -{2:.2f}, Gas - {3:.2f} at time {4}'.format(datetime.now().strftime("%d-%m-%y %H:%M:%S"),\
                pred_temp['yhat'][0],\
                pred_humidity['yhat'][0],\
                pred_gas['yhat'][0],\
                pred_gas['ds'][0].strftime("%d-%m-%y %H:%M:%S")) )          
        # write_api.close()    
        time.sleep(30)
# Out:
# Query sent to Influx at 15-07-22 23:06:22
# Data fed to predictor at 15-07-22 23:06:25
# Data sent to Influx at 15-07-22 23:06:45: Temperature-26.09, Humidity -48.65, Gas - 2122.39 at time 15-07-22 23:06:57
# Query sent to Influx at 15-07-22 23:07:15
# Data fed to predictor at 15-07-22 23:07:17
# Data sent to Influx at 15-07-22 23:07:37: Temperature-26.10, Humidity -48.64, Gas - 2122.21 at time 15-07-22 23:07:57
# Query sent to Influx at 15-07-22 23:08:07
# Data fed to predictor at 15-07-22 23:08:09
# Data sent to Influx at 15-07-22 23:08:29: Temperature-26.10, Humidity -48.62, Gas - 2122.06 at time 15-07-22 23:08:57
# Query sent to Influx at 15-07-22 23:08:59
# Data fed to predictor at 15-07-22 23:09:01
# Data sent to Influx at 15-07-22 23:09:23: Temperature-26.11, Humidity -48.62, Gas - 2121.98 at time 15-07-22 23:09:57
# Query sent to Influx at 15-07-22 23:09:53
# Data fed to predictor at 15-07-22 23:09:55
# Data sent to Influx at 15-07-22 23:10:13: Temperature-26.11, Humidity -48.63, Gas - 2121.98 at time 15-07-22 23:09:57
# Query sent to Influx at 15-07-22 23:10:43
# Data fed to predictor at 15-07-22 23:10:45
# Data sent to Influx at 15-07-22 23:11:03: Temperature-26.12, Humidity -48.62, Gas - 2122.18 at time 15-07-22 23:10:57
# Query sent to Influx at 15-07-22 23:11:33
# Data fed to predictor at 15-07-22 23:11:35
# Data sent to Influx at 15-07-22 23:11:54: Temperature-26.13, Humidity -48.61, Gas - 2122.16 at time 15-07-22 23:11:57
# Query sent to Influx at 15-07-22 23:12:25
# Data fed to predictor at 15-07-22 23:12:27
# Data sent to Influx at 15-07-22 23:12:44: Temperature-26.13, Humidity -48.60, Gas - 2121.36 at time 15-07-22 23:12:57
# Query sent to Influx at 15-07-22 23:13:14
# Data fed to predictor at 15-07-22 23:13:16
# Data sent to Influx at 15-07-22 23:13:32: Temperature-26.13, Humidity -48.59, Gas - 2122.31 at time 15-07-22 23:13:57
# Query sent to Influx at 15-07-22 23:14:02
# Data fed to predictor at 15-07-22 23:14:04
# Data sent to Influx at 15-07-22 23:14:20: Temperature-26.14, Humidity -48.57, Gas - 2121.63 at time 15-07-22 23:14:57
# Query sent to Influx at 15-07-22 23:14:50
# Data fed to predictor at 15-07-22 23:14:52
# Data sent to Influx at 15-07-22 23:15:09: Temperature-26.14, Humidity -48.59, Gas - 2121.35 at time 15-07-22 23:14:57
# Query sent to Influx at 15-07-22 23:15:39
# Data fed to predictor at 15-07-22 23:15:41
# Data sent to Influx at 15-07-22 23:15:59: Temperature-26.14, Humidity -48.58, Gas - 2121.39 at time 15-07-22 23:15:57
# Query sent to Influx at 15-07-22 23:16:29
# Data fed to predictor at 15-07-22 23:16:31
# Data sent to Influx at 15-07-22 23:16:53: Temperature-26.14, Humidity -48.57, Gas - 2120.74 at time 15-07-22 23:16:57
# Query sent to Influx at 15-07-22 23:17:23
# Data fed to predictor at 15-07-22 23:17:25
# Data sent to Influx at 15-07-22 23:17:43: Temperature-26.15, Humidity -48.57, Gas - 2121.09 at time 15-07-22 23:17:57
# Query sent to Influx at 15-07-22 23:18:13
# Data fed to predictor at 15-07-22 23:18:15
# Data sent to Influx at 15-07-22 23:18:36: Temperature-26.16, Humidity -48.56, Gas - 2120.75 at time 15-07-22 23:18:57
# Query sent to Influx at 15-07-22 23:19:06
# Data fed to predictor at 15-07-22 23:19:08
# Data sent to Influx at 15-07-22 23:19:27: Temperature-26.16, Humidity -48.57, Gas - 2120.83 at time 15-07-22 23:19:57
# Query sent to Influx at 15-07-22 23:19:57
# Data fed to predictor at 15-07-22 23:19:59
# Data sent to Influx at 15-07-22 23:20:19: Temperature-26.17, Humidity -48.57, Gas - 2120.74 at time 15-07-22 23:20:57
# Query sent to Influx at 15-07-22 23:20:49
# Data fed to predictor at 15-07-22 23:20:51
# Data sent to Influx at 15-07-22 23:21:12: Temperature-26.17, Humidity -48.56, Gas - 2120.37 at time 15-07-22 23:20:57
# Query sent to Influx at 15-07-22 23:21:42
# Data fed to predictor at 15-07-22 23:21:44
# Data sent to Influx at 15-07-22 23:22:06: Temperature-26.18, Humidity -48.56, Gas - 2120.12 at time 15-07-22 23:21:57
# Query sent to Influx at 15-07-22 23:22:36
# Data fed to predictor at 15-07-22 23:22:39
# Data sent to Influx at 15-07-22 23:23:00: Temperature-26.19, Humidity -48.54, Gas - 2120.13 at time 15-07-22 23:22:57
# Query sent to Influx at 15-07-22 23:23:30
# Data fed to predictor at 15-07-22 23:23:32
# Data sent to Influx at 15-07-22 23:24:14: Temperature-26.20, Humidity -48.56, Gas - 2119.98 at time 15-07-22 23:23:57
# Query sent to Influx at 15-07-22 23:24:44
# Data fed to predictor at 15-07-22 23:24:46
# Data sent to Influx at 15-07-22 23:25:05: Temperature-26.21, Humidity -48.55, Gas - 2120.33 at time 15-07-22 23:24:57
# Query sent to Influx at 15-07-22 23:25:35
# Data fed to predictor at 15-07-22 23:25:37
# Data sent to Influx at 15-07-22 23:25:54: Temperature-26.22, Humidity -48.52, Gas - 2120.61 at time 15-07-22 23:25:57
# Query sent to Influx at 15-07-22 23:26:24
# Data fed to predictor at 15-07-22 23:26:27
# Data sent to Influx at 15-07-22 23:27:00: Temperature-26.22, Humidity -48.53, Gas - 2120.26 at time 15-07-22 23:26:57
# Query sent to Influx at 15-07-22 23:27:30
# Data fed to predictor at 15-07-22 23:27:32
# Data sent to Influx at 15-07-22 23:27:55: Temperature-26.24, Humidity -48.52, Gas - 2120.14 at time 15-07-22 23:27:57
# Query sent to Influx at 15-07-22 23:28:25
# Data fed to predictor at 15-07-22 23:28:27
# Data sent to Influx at 15-07-22 23:28:48: Temperature-26.24, Humidity -48.51, Gas - 2120.28 at time 15-07-22 23:28:57
# Query sent to Influx at 15-07-22 23:29:18
# Data fed to predictor at 15-07-22 23:29:20
# Data sent to Influx at 15-07-22 23:29:43: Temperature-26.25, Humidity -48.50, Gas - 2120.46 at time 15-07-22 23:29:57
# Query sent to Influx at 15-07-22 23:30:13
# Data fed to predictor at 15-07-22 23:30:15
# Data sent to Influx at 15-07-22 23:30:36: Temperature-26.26, Humidity -48.51, Gas - 2120.32 at time 15-07-22 23:30:57
# Query sent to Influx at 15-07-22 23:31:06
# Data fed to predictor at 15-07-22 23:31:08
# Data sent to Influx at 15-07-22 23:31:29: Temperature-26.27, Humidity -48.47, Gas - 2120.61 at time 15-07-22 23:31:57
# Query sent to Influx at 15-07-22 23:31:59
# Data fed to predictor at 15-07-22 23:32:01
# Data sent to Influx at 15-07-22 23:32:23: Temperature-26.28, Humidity -48.46, Gas - 2119.98 at time 15-07-22 23:32:57
# Query sent to Influx at 15-07-22 23:32:53
# Data fed to predictor at 15-07-22 23:32:55
# Data sent to Influx at 15-07-22 23:33:17: Temperature-26.29, Humidity -48.46, Gas - 2120.28 at time 15-07-22 23:32:57
# Query sent to Influx at 15-07-22 23:33:47
# Data fed to predictor at 15-07-22 23:33:49
# Data sent to Influx at 15-07-22 23:34:10: Temperature-26.30, Humidity -48.44, Gas - 2120.14 at time 15-07-22 23:33:57
# Query sent to Influx at 15-07-22 23:34:40
# Data fed to predictor at 15-07-22 23:34:43
# Data sent to Influx at 15-07-22 23:35:03: Temperature-26.31, Humidity -48.44, Gas - 2119.91 at time 15-07-22 23:34:57
# Query sent to Influx at 15-07-22 23:35:33
# Data fed to predictor at 15-07-22 23:35:35
# Data sent to Influx at 15-07-22 23:36:00: Temperature-26.33, Humidity -48.42, Gas - 2120.23 at time 15-07-22 23:35:57
# Query sent to Influx at 15-07-22 23:36:30
# Data fed to predictor at 15-07-22 23:36:32
# Data sent to Influx at 15-07-22 23:36:55: Temperature-26.33, Humidity -48.41, Gas - 2120.19 at time 15-07-22 23:36:57
# Query sent to Influx at 15-07-22 23:37:25
# Data fed to predictor at 15-07-22 23:37:27
# Data sent to Influx at 15-07-22 23:37:47: Temperature-26.34, Humidity -48.40, Gas - 2119.83 at time 15-07-22 23:37:57
# Query sent to Influx at 15-07-22 23:38:17
# Data fed to predictor at 15-07-22 23:38:19
# Data sent to Influx at 15-07-22 23:38:40: Temperature-26.35, Humidity -48.38, Gas - 2120.29 at time 15-07-22 23:38:57
# Query sent to Influx at 15-07-22 23:39:10
# Data fed to predictor at 15-07-22 23:39:12
# Data sent to Influx at 15-07-22 23:39:30: Temperature-26.36, Humidity -48.37, Gas - 2120.19 at time 15-07-22 23:39:57
# Query sent to Influx at 15-07-22 23:40:00
# Data fed to predictor at 15-07-22 23:40:02
# Data sent to Influx at 15-07-22 23:40:21: Temperature-26.38, Humidity -48.36, Gas - 2119.84 at time 15-07-22 23:40:57
# Query sent to Influx at 15-07-22 23:40:51
# Data fed to predictor at 15-07-22 23:40:53
# Data sent to Influx at 15-07-22 23:41:12: Temperature-26.38, Humidity -48.36, Gas - 2119.36 at time 15-07-22 23:40:57
